# %% [markdown]
# <a href="https://colab.research.google.com/github/mahaairshad-shu/MechanicsPython2025/blob/main/Week%201/Wk1_Sess3_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![SHU](https://drive.google.com/uc?export=view&id=1oauWClN3B2tjg1AeVHtfjAXZg13d9HXL)

# %% [markdown]
# #**Modelling Mechanics of Sports Engineering**
# ##Week 1
# ###Session 3 - Practice tasks

# %% [markdown]
# <a target="_blank" href="https://github.com/mahaairshad-shu/MechanicsPython2025">
#   <img alt="Link to GitHub" src="https://img.shields.io/badge/link_to-GitHub_repo-blue?logo=github&labelColor=black">
#
# </a><a target="_blank" href="https://shuspace.shu.ac.uk/ultra/courses/_355862_1/outline">
#   <img alt="Access course folder" src="https://img.shields.io/badge/access_course_files-Folder-yellow">
# </a>

# %% [markdown]
# #Introduction
# This notebook contains practice tasks. Feel free to refer to the previous notebooks for help.
#
# * Variables and data types
# * Lists, indexing
# * NumPy

# %% [markdown]
# ✅ **Note: Make sure the AI assistant is turned off**
#
# *Tools> Settings> AI assistance> Hide generative AI features*

# %% [markdown]
# ###Exercise: 1
# A projectile is launched with an initial velocity of 20 m/s at an angle of 30 degrees above the horizontal.
# Calculate the horizontal and vertical components of the initial velocity using NumPy.
#
# *Solution:*
# ```
# Horizontal velocity: 17.32 m/s
# Vertical velocity: 9.99 m/s
# ```

# %%
# Exercise 1
# Write your code here

import numpy as np

# %% [markdown]
# ###Exercise: 2
# Following are the names and corresponding final finish times from Women's 100m Paris Olymics 2024. Rank and find the top three athletes based on this data.
#
# *Solution:*
#
# ```
# top_three_athletes = ['Julien', 'Sha', 'Melissa']
# ```

# %%
# Exercise 2
# Write your code here

athletes = np.array(['Marie', 'Tia', 'Twanisha', 'Melissa', 'Julien', 'Daryll', 'Sha', 'Mujinga'])
finishTimes = np.array([13.79, 11.04, 10.97, 10.92, 10.72, 10.96, 10.87, 10.99])

# you can use numpy functions to do this (hint: see argsort)

# %% [markdown]
# ##Exercise: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Solution*
#
#
# ```
# q = [13.66025404,  3.66025404]
# ```

# %%
# Exercise 3
# Write your code here
